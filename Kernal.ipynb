# %% [markdown]
# <a href="https://colab.research.google.com/github/hatkanchana/FinanceCBSL/blob/master/Kernal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import io
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-b0aa3e7f-e987-4f07-8b11-0be3c94f605f" name="files[]" multiple disabled />
#      <output id="result-b0aa3e7f-e987-4f07-8b11-0be3c94f605f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Bankwise Gross NPL Ratio.xlsx to Bankwise Gross NPL Ratio.xlsx

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = io.BytesIO(uploaded['Bankwise Gross NPL Ratio.xlsx'])

# %%
df = pd.read_excel(data , sheet_name = 'Sheet2',  skiprows = 0)
# displaying first few rows of the dataset
df.head()
# Out:
#        Date       NPL
# 0  30.09.17  1.559695
# 1  30.09.17  3.223211
# 2  30.09.17  2.757631
# 3  30.09.17  1.983835
# 4  30.09.17  3.236415

# %%
# List of five airlines to plot
airlines = ['30.09.17','31.12.17','30.09.18','31.12.18','30.09.19']

# Iterate through the five airlines
for airline in airlines:
    # Subset to the airline
    subset = df[df['Date'] == airline]

   #kernel : {‘gau’ | ‘cos’ | ‘biw’ | ‘epa’ | ‘tri’ | ‘triw’ } 

    # Draw the density plot
    sns.kdeplot(subset['NPL'],  kernel = 'gau', 
                 gridsize=100, cumulative= False, legend = True,
                 Label = airline)
    
# Plot formatting
plt.legend(prop={'size': 16}, title = 'Date')
plt.title('TITLE')
plt.xlabel('X')
plt.ylabel('Density')
plt.ylim(-.05, 0.25)
plt.xlim(0, 40)
# Out:
# (0, 40)

# %%
# List of five airlines to plot
airlines = ['30.09.17','31.12.17','30.09.18','31.12.18','30.09.19']

# Iterate through the five airlines
for airline in airlines:
    # Subset to the airline
    subset = df[df['Date'] == airline]
    
    # Draw the density plot
    sns.kdeplot(subset['NPL'],  kernel = 'gau', 
                 gridsize=100, cumulative= False, legend = True,
                 Label = airline,shade = True)
    
# Plot formatting
plt.legend(prop={'size': 16}, title = 'Quartile')
plt.title('TITLE')
plt.xlabel('X')
plt.ylabel('Density')
plt.ylim(-.05, 0.25)
plt.xlim(0, 40)
# Out:
# (0, 40)

# %%
# List of five airlines to plot
airlines = ['30.09.17','31.12.17','30.09.18','31.12.18','30.09.19']

# Iterate through the five airlines
for airline in airlines:
    # Subset to the airline
    subset = df[df['Date'] == airline]

   #kernel : {‘gau’ | ‘cos’ | ‘biw’ | ‘epa’ | ‘tri’ | ‘triw’ } 

    # Draw the density plot
    sns.kdeplot(subset['NPL'],  kernel = 'gau', 
                 gridsize=100, cumulative= True, legend = True,
                 Label = airline)
    
# Plot formatting
plt.legend(prop={'size': 16}, title = 'Date')
plt.title('TITLE')
plt.xlabel('X')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
# List of five airlines to plot
airlines = ['30.09.17','31.12.17','30.09.18','31.12.18','30.09.19']

# Iterate through the five airlines
for airline in airlines:
    # Subset to the airline
    subset = df[df['Date'] == airline]
    
    # Draw the density plot
    sns.kdeplot(subset['NPL'],  kernel = 'gau', 
                 gridsize=100, cumulative= True, legend = True,
                 Label = airline,shade = True)
    
# Plot formatting
plt.legend(prop={'size': 16}, title = 'Quartile')
plt.title('TITLE')
plt.xlabel('X')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
df = pd.read_excel(data , sheet_name = 'Gross NPL Ratio',  skiprows = 2)
# displaying first few rows of the dataset
df.head()
# Out:
#   Bank  30.09.17  31.12.17  30.09.18  31.12.18   30.09.19
# 0  NaN  1.559695  1.882000  2.773905  2.808674   4.614612
# 1  NaN  0.000000  0.000000  0.000000  0.000000   0.000000
# 2    A  3.223211  2.776938  4.406737  3.532091   5.210260
# 3    B  2.757631  3.549917  5.783586  6.021582  14.495858
# 4    C  1.983835  1.825711  2.752753  3.178453   5.011108

# %%
import seaborn as sns, numpy as np
sns.distplot(df['30.09.17'],bins=int(180/5));

# %%
import seaborn as sns, numpy as np
sns.distplot(df['31.12.17'],bins=int(180/5));

# %%
import seaborn as sns, numpy as np
sns.distplot(df['30.09.18'],bins=int(180/5));

# %%
import seaborn as sns, numpy as np
sns.distplot(df['31.12.18'],bins=int(180/5));

# %%
import seaborn as sns, numpy as np
sns.distplot(df['30.09.19'],bins=int(180/5));
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/lib/python3.6/dist-packages/numpy/lib/histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
